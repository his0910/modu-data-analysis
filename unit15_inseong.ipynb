# %%
# UNIT 15 테이블 형태의 데이터를 쉽게 다루도록 도와주는 pandas 라이브러리
# 2021.12.19

# %%
# 1. 위키피디아 데이터를 엑셀로 저장하기
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')
print(df)
# Out:
# [                                       Olympic Games
# 0                                        Main topics
# 1  Bids Boycotts Ceremonies Charter Host cities I...
# 2                                              Games
# 3  Summer Winter Youth African Asian European Pac...
# 4  .mw-parser-output .navbar{display:inline;font-...,                                              Team Summer Olympic Games  \
#                                   Team (IOC code)                    №
# 0                               Afghanistan (AFG)                   15
# 1                                   Algeria (ALG)                   14
# 2                                 Argentina (ARG)                   25
# 3                                   Armenia (ARM)                    7
# 4                         Australasia (ANZ) [ANZ]                    2
# ..                                            ...                  ...
# 152                          Zimbabwe (ZIM) [ZIM]                   14
# 153      Independent Olympic Athletes (IOA) [IOA]                    3
# 154  Independent Olympic Participants (IOP) [IOP]                    1
# 155                        Mixed team (ZZX) [ZZX]                    3
# 156                                        Totals                   32
#
#                                                                      \
#     Unnamed: 2_level_1 Unnamed: 3_level_1 Unnamed: 4_level_1  Total
# 0                    0                  0                  2      2
# 1                    5                  4                  8     17
# 2                   21                 26                 30     77
# 3                    2                  8                  8     18
# 4                    3                  4                  5     12
# ..                 ...                ...                ...    ...
# 152                  3                  4                  1      8
# 153                  1                  0                  1      2
# 154                  0                  1                  2      3
# 155                 11                  6                  8     25
# 156               5121               5085               5493  15703
#
#     Winter Olympic Games                                        \
#                        № Unnamed: 7_level_1 Unnamed: 8_level_1
# 0                      0                  0                  0
# 1                      3                  0                  0
# 2                     19                  0                  0
# 3                      7                  0                  0
# 4                      0                  0                  0
# ..                   ...                ...                ...
# 152                    1                  0                  0
# 153                    0                  0                  0
# 154                    0                  0                  0
# 155                    0                  0                  0
# 156                   23               1062               1060
#
#                              Combined total                      \
#     Unnamed: 9_level_1 Total              № Unnamed: 12_level_1
# 0                    0     0             15                   0
# 1                    0     0             17                   5
# 2                    0     0             44                  21
# 3                    0     0             14                   2
# 4                    0     0              2                   3
# ..                 ...   ...            ...                 ...
# 152                  0     0             15                   3
# 153                  0     0              3                   1
# 154                  0     0              1                   0
# 155                  0     0              3                   8
# 156               1051  3173             55                6187
#
#
#     Unnamed: 13_level_1 Unnamed: 14_level_1  Total
# 0                     0                   2      2
# 1                     4                   8     17
# 2                    26                  30     77
# 3                     8                   8     18
# 4                     4                   5     12
# ..                  ...                 ...    ...
# 152                   4                   1      8
# 153                   0                   1      2
# 154                   1                   2      3
# 155                   4                   4     16
# 156                6145                6544  18876
#
# [157 rows x 16 columns],                      Team (IOC code)  № Summer  № Winter  № Games
# 0                      Albania (ALB)         9         4       13
# 1               American Samoa (ASA)         9         1       10
# 2                      Andorra (AND)        12        12       24
# 3                       Angola (ANG)        10         0       10
# 4          Antigua and Barbuda (ANT)        11         0       11
# ..                               ...       ...       ...      ...
# 71     Republic of China (ROC) [ROC]         3         0        3
# 72                  Saar (SAA) [SAA]         1         0        1
# 73           North Yemen (YAR) [YAR]         2         0        2
# 74           South Yemen (YMD) [YMD]         1         0        1
# 75  Refugee Olympic Team (ROT) [ROT]         2         0        2
#
# [76 rows x 4 columns],      vte Summer Olympics medal table leaders by year  \
# 0  .mw-parser-output .div-col{margin-top:0.3em;co...
#
#    vte Summer Olympics medal table leaders by year.1
# 0  .mw-parser-output .div-col{margin-top:0.3em;co...  ,      vte Winter Olympics medal table leaders by year  \
# 0  1924: Norway 1928: Norway 1932: United States ...
#
#    vte Winter Olympics medal table leaders by year.1
# 0  1924: Norway 1928: Norway 1932: United States ...  ,              Unnamed: 0_level_0 Summer Games                     \
#                 Team (IOC code)            № Unnamed: 2_level_1
# 0                 Germany (GER)           17                201
# 1                    Saar (SAA)            1                  0
# 2  United Team of Germany (EUA)            3                 28
# 3            East Germany (GDR)            5                153
# 4            West Germany (FRG)            5                 56
# 5                         Total           35                438
#
#                                               Winter Games                     \
#   Unnamed: 3_level_1 Unnamed: 4_level_1 Total            № Unnamed: 7_level_1
# 0                205                246   652           12                 92
# 1                  0                  0     0            0                  0
# 2                 54                 36   118            3                  8
# 3                129                127   409            6                 39
# 4                 67                 81   204            6                 11
# 5                455                490  1383           21                150
#
#                                               Combined total  \
#   Unnamed: 8_level_1 Unnamed: 9_level_1 Total              №
# 0                 88                 60   240             29
# 1                  0                  0     0              1
# 2                  6                  5    19              6
# 3                 36                 35   110             11
# 4                 15                 13    39             11
# 5                145                113   408             46
#
#
#   Unnamed: 12_level_1 Unnamed: 13_level_1 Unnamed: 14_level_1 Total
# 0                 293                 293                 306   892
# 1                   0                   0                   0     0
# 2                  36                  60                  41   137
# 3                 192                 165                 162   519
# 4                  67                  82                  94   243
# 5                 588                 600                 603  1791  ,     0                                                  1
# 0 NaN  This section needs additional citations for ve...,                    Unnamed: 0_level_0 Summer Games                     \
#                       Team (IOC code)            № Unnamed: 2_level_1
# 0                        Russia (RUS)            6                149
# 1                Russian Empire (RU1)            3                  1
# 2                  Soviet Union (URS)            9                395
# 3                  Unified Team (EUN)            1                 45
# 4  Olympic Athletes from Russia (OAR)            0                  0
# 5                           ROC (ROC)            1                 20
# 6                               Total           20                610
#
#                                               Winter Games                     \
#   Unnamed: 3_level_1 Unnamed: 4_level_1 Total            № Unnamed: 7_level_1
# 0                125                152   426            6                 47
# 1                  4                  3     8            0                  0
# 2                319                296  1010            9                 78
# 3                 38                 29   112            1                  9
# 4                  0                  0     0            1                  2
# 5                 28                 23    71            0                  0
# 6                514                503  1627           17                136
#
#                                               Combined total  \
#   Unnamed: 8_level_1 Unnamed: 9_level_1 Total              №
# 0                 39                 35   121             12
# 1                  0                  0     0              3
# 2                 57                 59   194             18
# 3                  6                  8    23              2
# 4                  6                  9    17              1
# 5                  0                  0     0              1
# 6                108                111   355             37
#
#
#   Unnamed: 12_level_1 Unnamed: 13_level_1 Unnamed: 14_level_1 Total
# 0                 196                 164                 187   547
# 1                   1                   4                   3     8
# 2                 473                 376                 355  1204
# 3                  54                  44                  37   135
# 4                   2                   6                   9    17
# 5                  20                  28                  23    71
# 6                 746                 622                 614  1982  ,         Date                         Team                       Team.1  \
# 0       1912           as part of Austria           as part of Austria
# 1  1920–1936  Kingdom of Yugoslavia (YUG)  Kingdom of Yugoslavia (YUG)
# 2  1948–1988         SFR Yugoslavia (YUG)         SFR Yugoslavia (YUG)
# 3     1992 W                Croatia (CRO)               Slovenia (SLO)
# 4     1992 S                Croatia (CRO)               Slovenia (SLO)
# 5  1996–2006                Croatia (CRO)               Slovenia (SLO)
# 6      2008–                Croatia (CRO)               Slovenia (SLO)
# 7      2016–                Croatia (CRO)               Slovenia (SLO)
#
#                          Team.2                                  Team.3  \
# 0                           NaN                                     NaN
# 1   Kingdom of Yugoslavia (YUG)             Kingdom of Yugoslavia (YUG)
# 2          SFR Yugoslavia (YUG)                    SFR Yugoslavia (YUG)
# 3          SFR Yugoslavia (YUG)                    SFR Yugoslavia (YUG)
# 4  Bosnia and Herzegovina (BIH)  Independent Olympic Participants (IOP)
# 5  Bosnia and Herzegovina (BIH)                   North Macedonia (MKD)
# 6  Bosnia and Herzegovina (BIH)                   North Macedonia (MKD)
# 7  Bosnia and Herzegovina (BIH)                   North Macedonia (MKD)
#
#                                    Team.4  \
# 0                            Serbia (SRB)
# 1             Kingdom of Yugoslavia (YUG)
# 2                    SFR Yugoslavia (YUG)
# 3                    SFR Yugoslavia (YUG)
# 4  Independent Olympic Participants (IOP)
# 5             Serbia and Montenegro (SCG)
# 6                            Serbia (SRB)
# 7                            Serbia (SRB)
#
#                                    Team.5  \
# 0                            Serbia (SRB)
# 1             Kingdom of Yugoslavia (YUG)
# 2                    SFR Yugoslavia (YUG)
# 3                    SFR Yugoslavia (YUG)
# 4  Independent Olympic Participants (IOP)
# 5             Serbia and Montenegro (SCG)
# 6                            Serbia (SRB)
# 7                            Kosovo (KOS)
#
#                                    Team.6
# 0                                     NaN
# 1             Kingdom of Yugoslavia (YUG)
# 2                    SFR Yugoslavia (YUG)
# 3                    SFR Yugoslavia (YUG)
# 4  Independent Olympic Participants (IOP)
# 5             Serbia and Montenegro (SCG)
# 6                        Montenegro (MNE)
# 7                        Montenegro (MNE)  ,                                 Unnamed: 0_level_0 Summer Games  \
#                                    Team (IOC code)            №
# 0                              Serbia (SRB) (1912)            1
# 1                   Yugoslavia (YUG) (1920-1992 w)           16
# 2  Independent Olympic Participants (IOP) (1992 s)            1
# 3          Serbia and Montenegro (SCG) (1996-2006)            3
#
#                                                                  Winter Games  \
#   Unnamed: 2_level_1 Unnamed: 3_level_1 Unnamed: 4_level_1 Total            №
# 0                  0                  0                  0     0            0
# 1                 26                 29                 28    83           14
# 2                  0                  1                  2     3            0
# 3                  2                  4                  3     9            3
#
#                                                                   \
#   Unnamed: 7_level_1 Unnamed: 8_level_1 Unnamed: 9_level_1 Total
# 0                  0                  0                  0     0
# 1                  0                  3                  1     4
# 2                  0                  0                  0     0
# 3                  0                  0                  0     0
#
#   Combined total                                                              \
#                № Unnamed: 12_level_1 Unnamed: 13_level_1 Unnamed: 14_level_1
# 0              1                   0                   0                   0
# 1             30                  26                  32                  29
# 2              1                   0                   1                   2
# 3              6                   2                   4                   3
#
#
#   Total
# 0     0
# 1    87
# 2     3
# 3     9  ,    No.               Nation  Gold  Silver  Bronze  Total
# 0    1  United States (USA)  1075     846     752   2673
# 1    2         Russia (RUS)   610     514     503   1627
# 2    3        Germany (GER)   438     455     490   1383
# 3    4  Great Britain (GBR)   285     316     315    916
# 4    5          China (CHN)   262     199     173    634
# 5    6         France (FRA)   222     254     274    750
# 6    7          Italy (ITA)   217     188     213    618
# 7    8        Hungary (HUN)   181     154     176    511
# 8    9          Japan (JPN)   169     150     178    497
# 9   10      Australia (AUS)   164     170     209    543,    No.               Nation  Gold  Silver  Bronze  Total  Games
# 0    1  United States (USA)  1075     846     752   2673     28
# 1    2   Soviet Union (URS)   395     319     296   1010     10
# 2    3  Great Britain (GBR)   285     316     315    916     29
# 3    4          China (CHN)   262     199     173    634     11
# 4    5         France (FRA)   222     254     274    750     29
# 5    6          Italy (ITA)   217     188     213    618     28
# 6    7        Germany (GER)   201     205     246    652     17
# 7    8        Hungary (HUN)   181     154     176    511     27
# 8    9          Japan (JPN)   169     150     178    497     23
# 9   10      Australia (AUS)   164     170     209    543     29,    No.               Nation  Gold  Silver  Bronze  Total
# 0    1        Germany (GER)   150     145     113    408
# 1    2         Russia (RUS)   136     108     111    355
# 2    3         Norway (NOR)   132     125     111    368
# 3    4  United States (USA)   105     113      89    307
# 4    5         Canada (CAN)    73      64      62    199
# 5    6        Austria (AUT)    64      81      87    232
# 6    7         Sweden (SWE)    57      46      55    158
# 7    8    Switzerland (SUI)    55      46      52    153
# 8    9    Netherlands (NED)    45      44      41    130
# 9   10        Finland (FIN)    43      63      61    167,    No.               Nation  Gold  Silver  Bronze  Total
# 0    1  United States (USA)  1180     959     841   2980
# 1    2         Russia (RUS)   746     622     614   1982
# 2    3        Germany (GER)   588     600     603   1791
# 3    4  Great Britain (GBR)   296     320     332    948
# 4    5          China (CHN)   275     227     194    696
# 5    6         France (FRA)   258     289     327    874
# 6    7          Italy (ITA)   257     224     261    742
# 7    8         Sweden (SWE)   205     222     234    661
# 8    9         Norway (NOR)   192     176     160    528
# 9   10          Japan (JPN)   183     172     200    555,                                                      0  \
# 0    Summer Olympics (1896–2020)[edit] Rank.mw-pars...
# 1                                                 Rank
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 200                                                 43
# 201                                                 44
# 202                                                 45
# 203                                                 46
# 204                                   Totals (46 NOCs)
#
#                                                      1     2       3       4  \
# 0    Winter Olympics (1924–2018)[edit] RankNOCGoldS...   NaN     NaN     NaN
# 1    .mw-parser-output .tooltip-dotted{border-botto...  Gold  Silver  Bronze
# 2                                  United States (USA)  1075     846     752
# 3                                  Soviet Union (URS)*   395     319     296
# 4                                  Great Britain (GBR)   285     316     315
# ..                                                 ...   ...     ...     ...
# 200                                  New Zealand (NZL)     0       1       2
# 201                                  North Korea (PRK)     0       1       1
# 202                                      Denmark (DEN)     0       1       0
# 203                                      Romania (ROU)     0       0       1
# 204                                   Totals (46 NOCs)  1062    1060    1051
#
#          5
# 0      NaN
# 1    Total
# 2     2673
# 3     1010
# 4      916
# ..     ...
# 200      3
# 201      2
# 202      1
# 203      1
# 204   3173
#
# [205 rows x 6 columns],                   Rank  \
# 0                    1
# 1                    2
# 2                    3
# 3                    4
# 4                    5
# ..                 ...
# 150                147
# 151                147
# 152                147
# 153                147
# 154  Totals (154 NOCs)
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}NOC  \
# 0                                  United States (USA)
# 1                                  Soviet Union (URS)*
# 2                                  Great Britain (GBR)
# 3                                          China (CHN)
# 4                                         France (FRA)
# ..                                                 ...
# 150                                       Guyana (GUY)
# 151                                         Iraq (IRQ)
# 152                                    Mauritius (MRI)
# 153                                         Togo (TOG)
# 154                                  Totals (154 NOCs)
#
#      Gold  Silver  Bronze  Total
# 0    1075     846     752   2673
# 1     395     319     296   1010
# 2     285     316     315    916
# 3     262     199     173    634
# 4     222     254     274    750
# ..    ...     ...     ...    ...
# 150     0       0       1      1
# 151     0       0       1      1
# 152     0       0       1      1
# 153     0       0       1      1
# 154  5474    5434    5909  16817
#
# [155 rows x 6 columns],                 Rank                                  NOC  Gold  Silver  \
# 0                  1                         Norway (NOR)   132     125
# 1                  2                  United States (USA)   105     113
# 2                  3                        Germany (GER)    92      88
# 3                  4                  Soviet Union (URS)*    78      57
# 4                  5                         Canada (CAN)    73      64
# 5                  6                        Austria (AUT)    64      81
# 6                  7                         Sweden (SWE)    57      46
# 7                  8                    Switzerland (SUI)    56      45
# 8                  9                         Russia (RUS)    47      39
# 9                 10                    Netherlands (NED)    45      44
# 10                11                        Finland (FIN)    43      63
# 11                12                          Italy (ITA)    40      36
# 12                13                  East Germany (GDR)*    39      36
# 13                14                         France (FRA)    36      35
# 14                15                    South Korea (KOR)    31      25
# 15                16                          Japan (JPN)    14      22
# 16                17                          China (CHN)    13      28
# 17                18                  West Germany (FRG)*    11      15
# 18                19                  Great Britain (GBR)    11       4
# 19                20                 Czech Republic (CZE)     9      11
# 20                21                  Unified Team (EUN)*     9       6
# 21                22        United Team of Germany (EUA)*     8       6
# 22                23                        Belarus (BLR)     8       5
# 23                24                         Poland (POL)     7       7
# 24                25                      Australia (AUS)     5       5
# 25                26                        Croatia (CRO)     4       6
# 26                27                        Estonia (EST)     4       2
# 27                28                       Slovakia (SVK)     3       4
# 28                29                        Ukraine (UKR)     3       1
# 29                30                Czechoslovakia (TCH)*     2       8
# 30                31  Olympic Athletes from Russia (OAR)*     2       6
# 31                32                       Slovenia (SLO)     2       5
# 32                33                  Liechtenstein (LIE)     2       2
# 33                34                         Latvia (LAT)     1       3
# 34                35                     Kazakhstan (KAZ)     1       3
# 35                36                        Hungary (HUN)     1       2
# 36                37                        Belgium (BEL)     1       2
# 37                37                       Bulgaria (BUL)     1       2
# 38                39                          Spain (ESP)     1       0
# 39                40                     Uzbekistan (UZB)     1       0
# 40                41                    Yugoslavia (YUG)*     0       3
# 41                42                     Luxembourg (LUX)     0       2
# 42                43                    New Zealand (NZL)     0       1
# 43                44                    North Korea (PRK)     0       1
# 44                45                        Denmark (DEN)     0       1
# 45                46                        Romania (ROU)     0       0
# 46  Totals (46 NOCs)                     Totals (46 NOCs)  1062    1060
#
#     Bronze  Total
# 0      111    368
# 1       89    307
# 2       60    240
# 3       59    194
# 4       62    199
# 5       87    232
# 6       55    158
# 7       52    153
# 8       35    121
# 9       41    130
# 10      61    167
# 11      48    124
# 12      35    110
# 13      53    124
# 14      14     70
# 15      22     58
# 16      21     62
# 17      13     39
# 18      17     32
# 19      11     31
# 20       8     23
# 21       5     19
# 22       5     18
# 23       8     22
# 24       5     15
# 25       1     11
# 26       1      7
# 27       1      8
# 28       4      8
# 29      15     25
# 30       9     17
# 31      10     17
# 32       6     10
# 33       5      9
# 34       4      8
# 35       4      7
# 36       3      6
# 37       3      6
# 38       3      4
# 39       0      1
# 40       1      4
# 41       0      2
# 42       2      3
# 43       1      2
# 44       0      1
# 45       1      1
# 46    1051   3173  ,                   Rank                  NOC  Gold  Silver  Bronze  Total
# 0                    1  United States (USA)  1180     959     841   2980
# 1                    2  Soviet Union (URS)*   473     376     355   1204
# 2                    3  Great Britain (GBR)   296     320     332    948
# 3                    4        Germany (GER)   293     293     306    892
# 4                    5          China (CHN)   275     227     194    696
# ..                 ...                  ...   ...     ...     ...    ...
# 152                149         Guyana (GUY)     0       0       1      1
# 153                149           Iraq (IRQ)     0       0       1      1
# 154                149      Mauritius (MRI)     0       0       1      1
# 155                149           Togo (TOG)     0       0       1      1
# 156  Totals (156 NOCs)    Totals (156 NOCs)  6536    6494    6960  19990
#
# [157 rows x 6 columns],                                                    0  \
# 0  .mw-parser-output .citation{word-wrap:break-wo...
#
#                                                    1
# 0  SRB , YUG to 1992 , YUG/SCG Serbia (SRB, 1912,...  ,                                                    0  \
# 0  BIZ Belize participated under its former name ...
#
#                                                    1
# 0  GHA Prior to Ghana's independence in 1957, Gol...  ,                                                    0  \
# 0  A Brunei's participation in the 1988 Games con...
#
#                                                    1
# 0  F India's athletes originally competed at the ...  ,                                                    0  \
# 0  H The Bulgarian Olympic Committee claims that ...
#
#                                                    1
# 0  The nationalities of many medalists at the 190...  ,                       vte Olympic Games medal tables  \
# 0  Olympic medal All-time Olympic Games medal tab...
# 1                               Summer Olympic Games
# 2                               Winter Olympic Games
# 3  Lists of Olympic medalists List of stripped Ol...
#
#                     vte Olympic Games medal tables.1
# 0  Olympic medal All-time Olympic Games medal tab...
# 1  1896 1900 1904 1908 1912 1920 1924 1928 1932 1...
# 2  1924 1928 1932 1936 1948 1952 1956 1960 1964 1...
# 3  Lists of Olympic medalists List of stripped Ol...  ,                       vteOlympic Games medal winners  \
# 0  Olympic medal All-time Olympic Games medal tab...
# 1                               Summer Olympic Games
# 2                               Winter Olympic Games
# 3  Lists of Olympic medalists List of stripped Ol...
#
#                     vteOlympic Games medal winners.1
# 0  Olympic medal All-time Olympic Games medal tab...
# 1  1896 1900 1904 1908 1912 1920 1924 1928 1932 1...
# 2  1924 1928 1932 1936 1948 1952 1956 1960 1964 1...
# 3  Lists of Olympic medalists List of stripped Ol...  ,                        vteLists of Olympic medalists  \
# 0                                      Summer sports
# 1                                      Winter sports
# 2                                Discontinued sports
# 3                                  Unofficial sports
# 4  Olympic sports Olympic medal All-time Olympic ...
#
#                      vteLists of Olympic medalists.1
# 0  Archery Artistic swimming Athletics men women ...
# 1  Alpine skiing Biathlon Bobsleigh Cross-country...
# 2  Basque pelota Cricket Croquet Jeu de paume Lac...
# 3                                   Art competitions
# 4  Olympic sports Olympic medal All-time Olympic ...  ,                                    vte Olympic Games  \
# 0  Ceremonies People who opened the Olympics Keep...
# 1                                        SummerGames
# 2                                       Winter Games
# 3  †Cancelled due to World War I ‡Cancelled due t...
#
#                                  vte Olympic Games.1  \
# 0  Ceremonies People who opened the Olympics Keep...
# 1  1896 Athens 1900 Paris 1904 St. Louis 1908 Lon...
# 2  1924 Chamonix 1928 St. Moritz 1932 Lake Placid...
# 3  †Cancelled due to World War I ‡Cancelled due t...
#
#                                  vte Olympic Games.2
# 0  Ceremonies People who opened the Olympics Keep...
# 1                                                NaN
# 2                                                NaN
# 3  †Cancelled due to World War I ‡Cancelled due t...  ,   vte Olympics and Paralympics statistics  \
# 0              Medalists and medal tables
# 1                      Multiple medalists
# 2                 Multiple gold medalists
# 3                        Other statistics
#
#            vte Olympics and Paralympics statistics.1
# 0  Lists of Olympic medalists first Olympic gold ...
# 1  Multiple Olympic medalists at a single Games i...
# 2  Multiple Olympic gold medalists at a single Ga...
# 3  Olympic medals in different sports at Summer a...  ,      vte Summer Olympics medal table leaders by year  \
# 0  1896: United States 1900: France 1904: United ...
#
#    vte Summer Olympics medal table leaders by year.1
# 0  1896: United States 1900: France 1904: United ...  ,      vte Winter Olympics medal table leaders by year  \
# 0  1924: Norway 1928: Norway 1932: United States ...
#
#    vte Winter Olympics medal table leaders by year.1
# 0  1924: Norway 1928: Norway 1932: United States ...  ,   vteMedal tables of Olympics, Paralympics and World Championships by sport  \
# 0                         Olympic Games(HostsMedals)
# 1                      Paralympic Games(HostsMedals)
# 2                     WorldChampionshipsorWorld Cups
# 3    List of international rankings Lists by country
#
#   vteMedal tables of Olympics, Paralympics and World Championships by sport.1
# 0  Alpine skiing Archery Athletics Badminton Band...
# 1  Alpine skiing Archery Athletics Biathlon Bocci...
# 2  Alpine skiing American football Aquatics Arche...
# 3    List of international rankings Lists by country                           ]

# %%
df[1]
# Out:
#                                              Team Summer Olympic Games  \
#                                   Team (IOC code)                    №
# 0                               Afghanistan (AFG)                   15
# 1                                   Algeria (ALG)                   14
# 2                                 Argentina (ARG)                   25
# 3                                   Armenia (ARM)                    7
# 4                         Australasia (ANZ) [ANZ]                    2
# ..                                            ...                  ...
# 152                          Zimbabwe (ZIM) [ZIM]                   14
# 153      Independent Olympic Athletes (IOA) [IOA]                    3
# 154  Independent Olympic Participants (IOP) [IOP]                    1
# 155                        Mixed team (ZZX) [ZZX]                    3
# 156                                        Totals                   32
#
#                                                                      \
#     Unnamed: 2_level_1 Unnamed: 3_level_1 Unnamed: 4_level_1  Total
# 0                    0                  0                  2      2
# 1                    5                  4                  8     17
# 2                   21                 26                 30     77
# 3                    2                  8                  8     18
# 4                    3                  4                  5     12
# ..                 ...                ...                ...    ...
# 152                  3                  4                  1      8
# 153                  1                  0                  1      2
# 154                  0                  1                  2      3
# 155                 11                  6                  8     25
# 156               5121               5085               5493  15703
#
#     Winter Olympic Games                                        \
#                        № Unnamed: 7_level_1 Unnamed: 8_level_1
# 0                      0                  0                  0
# 1                      3                  0                  0
# 2                     19                  0                  0
# 3                      7                  0                  0
# 4                      0                  0                  0
# ..                   ...                ...                ...
# 152                    1                  0                  0
# 153                    0                  0                  0
# 154                    0                  0                  0
# 155                    0                  0                  0
# 156                   23               1062               1060
#
#                              Combined total                      \
#     Unnamed: 9_level_1 Total              № Unnamed: 12_level_1
# 0                    0     0             15                   0
# 1                    0     0             17                   5
# 2                    0     0             44                  21
# 3                    0     0             14                   2
# 4                    0     0              2                   3
# ..                 ...   ...            ...                 ...
# 152                  0     0             15                   3
# 153                  0     0              3                   1
# 154                  0     0              1                   0
# 155                  0     0              3                   8
# 156               1051  3173             55                6187
#
#
#     Unnamed: 13_level_1 Unnamed: 14_level_1  Total
# 0                     0                   2      2
# 1                     4                   8     17
# 2                    26                  30     77
# 3                     8                   8     18
# 4                     4                   5     12
# ..                  ...                 ...    ...
# 152                   4                   1      8
# 153                   0                   1      2
# 154                   1                   2      3
# 155                   4                   4     16
# 156                6145                6544  18876
#
# [157 rows x 16 columns]

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header = 0, index_col = 0)
df[1]
# Out:
#                                              Summer Olympic Games  \
# Team
# Team (IOC code)                                                 №
# Afghanistan (AFG)                                              15
# Algeria (ALG)                                                  14
# Argentina (ARG)                                                25
# Armenia (ARM)                                                   7
# ...                                                           ...
# Zimbabwe (ZIM) [ZIM]                                           14
# Independent Olympic Athletes (IOA) [IOA]                        3
# Independent Olympic Participants (IOP) [IOP]                    1
# Mixed team (ZZX) [ZZX]                                          3
# Totals                                                         32
#
#                                               Summer Olympic Games.1  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    5.0
# Argentina (ARG)                                                 21.0
# Armenia (ARM)                                                    2.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             3.0
# Independent Olympic Athletes (IOA) [IOA]                         1.0
# Independent Olympic Participants (IOP) [IOP]                     0.0
# Mixed team (ZZX) [ZZX]                                          11.0
# Totals                                                        5121.0
#
#                                               Summer Olympic Games.2  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    4.0
# Argentina (ARG)                                                 26.0
# Armenia (ARM)                                                    8.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             4.0
# Independent Olympic Athletes (IOA) [IOA]                         0.0
# Independent Olympic Participants (IOP) [IOP]                     1.0
# Mixed team (ZZX) [ZZX]                                           6.0
# Totals                                                        5085.0
#
#                                               Summer Olympic Games.3  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                2.0
# Algeria (ALG)                                                    8.0
# Argentina (ARG)                                                 30.0
# Armenia (ARM)                                                    8.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             1.0
# Independent Olympic Athletes (IOA) [IOA]                         1.0
# Independent Olympic Participants (IOP) [IOP]                     2.0
# Mixed team (ZZX) [ZZX]                                           8.0
# Totals                                                        5493.0
#
#                                              Summer Olympic Games.4  \
# Team
# Team (IOC code)                                               Total
# Afghanistan (AFG)                                                 2
# Algeria (ALG)                                                    17
# Argentina (ARG)                                                  77
# Armenia (ARM)                                                    18
# ...                                                             ...
# Zimbabwe (ZIM) [ZIM]                                              8
# Independent Olympic Athletes (IOA) [IOA]                          2
# Independent Olympic Participants (IOP) [IOP]                      3
# Mixed team (ZZX) [ZZX]                                           25
# Totals                                                        15703
#
#                                              Winter Olympic Games  \
# Team
# Team (IOC code)                                                 №
# Afghanistan (AFG)                                               0
# Algeria (ALG)                                                   3
# Argentina (ARG)                                                19
# Armenia (ARM)                                                   7
# ...                                                           ...
# Zimbabwe (ZIM) [ZIM]                                            1
# Independent Olympic Athletes (IOA) [IOA]                        0
# Independent Olympic Participants (IOP) [IOP]                    0
# Mixed team (ZZX) [ZZX]                                          0
# Totals                                                         23
#
#                                               Winter Olympic Games.1  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    0.0
# Argentina (ARG)                                                  0.0
# Armenia (ARM)                                                    0.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             0.0
# Independent Olympic Athletes (IOA) [IOA]                         0.0
# Independent Olympic Participants (IOP) [IOP]                     0.0
# Mixed team (ZZX) [ZZX]                                           0.0
# Totals                                                        1062.0
#
#                                               Winter Olympic Games.2  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    0.0
# Argentina (ARG)                                                  0.0
# Armenia (ARM)                                                    0.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             0.0
# Independent Olympic Athletes (IOA) [IOA]                         0.0
# Independent Olympic Participants (IOP) [IOP]                     0.0
# Mixed team (ZZX) [ZZX]                                           0.0
# Totals                                                        1060.0
#
#                                               Winter Olympic Games.3  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    0.0
# Argentina (ARG)                                                  0.0
# Armenia (ARM)                                                    0.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             0.0
# Independent Olympic Athletes (IOA) [IOA]                         0.0
# Independent Olympic Participants (IOP) [IOP]                     0.0
# Mixed team (ZZX) [ZZX]                                           0.0
# Totals                                                        1051.0
#
#                                              Winter Olympic Games.4  \
# Team
# Team (IOC code)                                               Total
# Afghanistan (AFG)                                                 0
# Algeria (ALG)                                                     0
# Argentina (ARG)                                                   0
# Armenia (ARM)                                                     0
# ...                                                             ...
# Zimbabwe (ZIM) [ZIM]                                              0
# Independent Olympic Athletes (IOA) [IOA]                          0
# Independent Olympic Participants (IOP) [IOP]                      0
# Mixed team (ZZX) [ZZX]                                            0
# Totals                                                         3173
#
#                                              Combined total  Combined total.1  \
# Team
# Team (IOC code)                                           №               NaN
# Afghanistan (AFG)                                        15               0.0
# Algeria (ALG)                                            17               5.0
# Argentina (ARG)                                          44              21.0
# Armenia (ARM)                                            14               2.0
# ...                                                     ...               ...
# Zimbabwe (ZIM) [ZIM]                                     15               3.0
# Independent Olympic Athletes (IOA) [IOA]                  3               1.0
# Independent Olympic Participants (IOP) [IOP]              1               0.0
# Mixed team (ZZX) [ZZX]                                    3               8.0
# Totals                                                   55            6187.0
#
#                                               Combined total.2  \
# Team
# Team (IOC code)                                            NaN
# Afghanistan (AFG)                                          0.0
# Algeria (ALG)                                              4.0
# Argentina (ARG)                                           26.0
# Armenia (ARM)                                              8.0
# ...                                                        ...
# Zimbabwe (ZIM) [ZIM]                                       4.0
# Independent Olympic Athletes (IOA) [IOA]                   0.0
# Independent Olympic Participants (IOP) [IOP]               1.0
# Mixed team (ZZX) [ZZX]                                     4.0
# Totals                                                  6145.0
#
#                                               Combined total.3  \
# Team
# Team (IOC code)                                            NaN
# Afghanistan (AFG)                                          2.0
# Algeria (ALG)                                              8.0
# Argentina (ARG)                                           30.0
# Armenia (ARM)                                              8.0
# ...                                                        ...
# Zimbabwe (ZIM) [ZIM]                                       1.0
# Independent Olympic Athletes (IOA) [IOA]                   1.0
# Independent Olympic Participants (IOP) [IOP]               2.0
# Mixed team (ZZX) [ZZX]                                     4.0
# Totals                                                  6544.0
#
#                                              Combined total.4
# Team
# Team (IOC code)                                         Total
# Afghanistan (AFG)                                           2
# Algeria (ALG)                                              17
# Argentina (ARG)                                            77
# Armenia (ARM)                                              18
# ...                                                       ...
# Zimbabwe (ZIM) [ZIM]                                        8
# Independent Olympic Athletes (IOA) [IOA]                    2
# Independent Olympic Participants (IOP) [IOP]                3
# Mixed team (ZZX) [ZZX]                                     16
# Totals                                                  18876
#
# [158 rows x 15 columns]

# %%
summer = df[1].iloc[:,:5]
summer
# Out:
#                                              Summer Olympic Games  \
# Team
# Team (IOC code)                                                 №
# Afghanistan (AFG)                                              15
# Algeria (ALG)                                                  14
# Argentina (ARG)                                                25
# Armenia (ARM)                                                   7
# ...                                                           ...
# Zimbabwe (ZIM) [ZIM]                                           14
# Independent Olympic Athletes (IOA) [IOA]                        3
# Independent Olympic Participants (IOP) [IOP]                    1
# Mixed team (ZZX) [ZZX]                                          3
# Totals                                                         32
#
#                                               Summer Olympic Games.1  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    5.0
# Argentina (ARG)                                                 21.0
# Armenia (ARM)                                                    2.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             3.0
# Independent Olympic Athletes (IOA) [IOA]                         1.0
# Independent Olympic Participants (IOP) [IOP]                     0.0
# Mixed team (ZZX) [ZZX]                                          11.0
# Totals                                                        5121.0
#
#                                               Summer Olympic Games.2  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    4.0
# Argentina (ARG)                                                 26.0
# Armenia (ARM)                                                    8.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             4.0
# Independent Olympic Athletes (IOA) [IOA]                         0.0
# Independent Olympic Participants (IOP) [IOP]                     1.0
# Mixed team (ZZX) [ZZX]                                           6.0
# Totals                                                        5085.0
#
#                                               Summer Olympic Games.3  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                2.0
# Algeria (ALG)                                                    8.0
# Argentina (ARG)                                                 30.0
# Armenia (ARM)                                                    8.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             1.0
# Independent Olympic Athletes (IOA) [IOA]                         1.0
# Independent Olympic Participants (IOP) [IOP]                     2.0
# Mixed team (ZZX) [ZZX]                                           8.0
# Totals                                                        5493.0
#
#                                              Summer Olympic Games.4
# Team
# Team (IOC code)                                               Total
# Afghanistan (AFG)                                                 2
# Algeria (ALG)                                                    17
# Argentina (ARG)                                                  77
# Armenia (ARM)                                                    18
# ...                                                             ...
# Zimbabwe (ZIM) [ZIM]                                              8
# Independent Olympic Athletes (IOA) [IOA]                          2
# Independent Olympic Participants (IOP) [IOP]                      3
# Mixed team (ZZX) [ZZX]                                           25
# Totals                                                        15703
#
# [158 rows x 5 columns]

# %%
summer.columns = ['경기수', '금', '은', '동', '계']
print(summer)
# Out:
#                                              경기수       금       은       동  \
# Team
# Team (IOC code)                                №     NaN     NaN     NaN
# Afghanistan (AFG)                             15     0.0     0.0     2.0
# Algeria (ALG)                                 14     5.0     4.0     8.0
# Argentina (ARG)                               25    21.0    26.0    30.0
# Armenia (ARM)                                  7     2.0     8.0     8.0
# ...                                           ..     ...     ...     ...
# Zimbabwe (ZIM) [ZIM]                          14     3.0     4.0     1.0
# Independent Olympic Athletes (IOA) [IOA]       3     1.0     0.0     1.0
# Independent Olympic Participants (IOP) [IOP]   1     0.0     1.0     2.0
# Mixed team (ZZX) [ZZX]                         3    11.0     6.0     8.0
# Totals                                        32  5121.0  5085.0  5493.0
#
#                                                   계
# Team
# Team (IOC code)                               Total
# Afghanistan (AFG)                                 2
# Algeria (ALG)                                    17
# Argentina (ARG)                                  77
# Armenia (ARM)                                    18
# ...                                             ...
# Zimbabwe (ZIM) [ZIM]                              8
# Independent Olympic Athletes (IOA) [IOA]          2
# Independent Olympic Participants (IOP) [IOP]      3
# Mixed team (ZZX) [ZZX]                           25
# Totals                                        15703
#
# [158 rows x 5 columns]

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header = 0, index_col = 0) 
summer = df[1].iloc[:,:5]
summer.columns = ['경기수', '금', '은', '동', '계']
print(summer.sort_values('금', ascending = False))
# Out:
#                                          경기수       금       은       동      계
# Team
# Totals                                    32  5121.0  5085.0  5493.0  15703
# United States (USA) [P] [Q] [R] [Z] [F]   28  1075.0   846.0   752.0   2673
# Soviet Union (URS) [URS]                   9   395.0   319.0   296.0   1010
# Great Britain (GBR) [GBR] [Z]             29   285.0   316.0   315.0    916
# China (CHN) [CHN]                         11   262.0   199.0   173.0    634
# ...                                       ..     ...     ...     ...    ...
# Olympic Athletes from Russia (OAR) [OAR]   0     0.0     0.0     0.0      0
# San Marino (SMR)                          16     0.0     1.0     2.0      3
# Saudi Arabia (KSA)                        12     0.0     2.0     2.0      4
# Lebanon (LIB)                             18     0.0     2.0     2.0      4
# Team (IOC code)                            №     NaN     NaN     NaN  Total
#
# [158 rows x 5 columns]

# %%
summer.to_excel('하계올림픽메달.xlsx')

# %%
# 2. pandas란
# 3. 데이터 프레임 기초
import pandas as pd
index = pd.date_range('1/1/2000', periods =8)
print(index)
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df
# Out:
#                    A         B         C
# 2000-01-01  0.880023  0.647701  0.269906
# 2000-01-02  0.791922  0.952411  0.895657
# 2000-01-03  0.819700  0.642709  0.912509
# 2000-01-04  0.298991  0.967682  0.316432
# 2000-01-05  0.602900  0.754553  0.956351
# 2000-01-06  0.079604  0.390932  0.191745
# 2000-01-07  0.823338  0.357523  0.880602
# 2000-01-08  0.885908  0.163166  0.034562

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
print(df['B'])
# Out:
# 2000-01-01    0.719627
# 2000-01-02    0.563826
# 2000-01-03    0.435088
# 2000-01-04    0.872611
# 2000-01-05    0.192343
# 2000-01-06    0.455507
# 2000-01-07    0.340158
# 2000-01-08    0.973502
# Freq: D, Name: B, dtype: float64

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
print(df['B'] > 0.4)
# Out:
# 2000-01-01     True
# 2000-01-02    False
# 2000-01-03    False
# 2000-01-04    False
# 2000-01-05     True
# 2000-01-06     True
# 2000-01-07     True
# 2000-01-08     True
# Freq: D, Name: B, dtype: bool

# %%
df2 = df[df['B'] > 0.4]
df2
# Out:
#                    A         B         C
# 2000-01-01  0.630491  0.974810  0.624320
# 2000-01-05  0.880784  0.561411  0.321211
# 2000-01-06  0.801924  0.954598  0.604137
# 2000-01-07  0.792285  0.533952  0.190472
# 2000-01-08  0.801960  0.482905  0.164780

# %%
df2 = df2.T
df2
# Out:
#    2000-01-01  2000-01-05  2000-01-06  2000-01-07  2000-01-08
# A    0.630491    0.880784    0.801924    0.792285    0.801960
# B    0.974810    0.561411    0.954598    0.533952    0.482905
# C    0.624320    0.321211    0.604137    0.190472    0.164780

# %%
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B']  # A열의 값을 B열의 값으로 나눈 값을 D열에 저장
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.808049  0.576237  0.307652  1.402287
# 2000-01-02  0.649326  0.278014  0.715881  2.335585
# 2000-01-03  0.873830  0.642505  0.003618  1.360037
# 2000-01-04  0.311839  0.601659  0.927092  0.518298
# 2000-01-05  0.754396  0.412581  0.215999  1.828478
# 2000-01-06  0.504210  0.269055  0.700180  1.874003
# 2000-01-07  0.165146  0.664790  0.992638  0.248418
# 2000-01-08  0.548727  0.613305  0.307956  0.894705

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B']
df['E'] = np.sum(df, axis = 1)  #행 우선 계산 값을 E 열에 저장
df.head()
# Out:
#                    A         B         C         D         E
# 2000-01-01  0.233295  0.036316  0.753494  6.424021  7.447125
# 2000-01-02  0.326571  0.724533  0.855275  0.450733  2.357113
# 2000-01-03  0.886919  0.765047  0.934546  1.159300  3.745811
# 2000-01-04  0.241929  0.081323  0.476494  2.974918  3.774663
# 2000-01-05  0.529749  0.760029  0.526533  0.697011  2.513321

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B']
df['E'] = np.sum(df, axis = 1)
df = df.sub(df['A'], axis =0)  #A열의 데이터를 기준으로 열 우선 계산
df.head()
# Out:
#               A         B         C         D         E
# 2000-01-01  0.0  0.209475  0.353192  0.068923  0.693377
# 2000-01-02  0.0 -0.189520 -0.483424  0.306636  2.466946
# 2000-01-03  0.0  0.940981  0.887336  0.000888  1.907226
# 2000-01-04  0.0 -0.646400 -0.095706  1.903285  4.125631
# 2000-01-05  0.0  0.489218 -0.080655  0.063041  1.559743

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B']
df['E'] = np.sum(df, axis = 1)
df = df.sub(df['A'], axis =0)  
df = df.div(df['C'], axis = 0)   #C열의 데이터를 기준으로 열 우선 계산
df.to_csv('test.csv')
df.head()
# Out:
#               A         B    C         D         E
# 2000-01-01 -0.0  0.894114  1.0 -5.350016 -8.108410
# 2000-01-02 -0.0  0.690971  1.0 -1.483717 -5.247961
# 2000-01-03 -0.0 -0.027127  1.0 -0.396859 -9.440403
# 2000-01-04  0.0 -0.118411  1.0  1.950546  4.713327
# 2000-01-05  0.0  1.383866  1.0  0.115604  6.091518

# %%
# 4. pandas로 인구 구조 분석하기
import pandas as pd
df = pd.read_csv('age_gangnam.csv', encoding='cp949', index_col = 0)
df.head()
# Out:
#                             2021년11월_계_총인구수 2021년11월_계_연령구간인구수 2021년11월_계_0세  \
# 행정구역
# 서울특별시  (1100000000)               9,520,880          9,520,880        43,492
# 서울특별시 종로구 (1111000000)              145,073            145,073           486
# 서울특별시 종로구 청운효자동(1111051500)          12,006             12,006            43
# 서울특별시 종로구 사직동(1111053000)             9,367              9,367            38
# 서울특별시 종로구 삼청동(1111054000)             2,467              2,467             7
#
#                             2021년11월_계_1세 2021년11월_계_2세 2021년11월_계_3세  \
# 행정구역
# 서울특별시  (1100000000)                45,054        49,318        51,995
# 서울특별시 종로구 (1111000000)                475           557           576
# 서울특별시 종로구 청운효자동(1111051500)            48            58            54
# 서울특별시 종로구 사직동(1111053000)              27            40            46
# 서울특별시 종로구 삼청동(1111054000)               5             3            10
#
#                             2021년11월_계_4세 2021년11월_계_5세 2021년11월_계_6세  \
# 행정구역
# 서울특별시  (1100000000)                56,210        63,757        67,763
# 서울특별시 종로구 (1111000000)                664           773           848
# 서울특별시 종로구 청운효자동(1111051500)            80            74            96
# 서울특별시 종로구 사직동(1111053000)              55            67            74
# 서울특별시 종로구 삼청동(1111054000)              14             6            17
#
#                             2021년11월_계_7세  ... 2021년11월_계_91세 2021년11월_계_92세  \
# 행정구역                                       ...
# 서울특별시  (1100000000)                66,950  ...          8,147          6,779
# 서울특별시 종로구 (1111000000)                859  ...            183            139
# 서울특별시 종로구 청운효자동(1111051500)            93  ...             10             10
# 서울특별시 종로구 사직동(1111053000)              71  ...             15             19
# 서울특별시 종로구 삼청동(1111054000)               8  ...              7              2
#
#                             2021년11월_계_93세 2021년11월_계_94세 2021년11월_계_95세  \
# 행정구역
# 서울특별시  (1100000000)                  5,328          4,048          2,587
# 서울특별시 종로구 (1111000000)                 114            104             71
# 서울특별시 종로구 청운효자동(1111051500)             10              7              7
# 서울특별시 종로구 사직동(1111053000)                6              7              8
# 서울특별시 종로구 삼청동(1111054000)                4              3              1
#
#                             2021년11월_계_96세 2021년11월_계_97세 2021년11월_계_98세  \
# 행정구역
# 서울특별시  (1100000000)                  1,862          1,368          1,274
# 서울특별시 종로구 (1111000000)                  45             28             25
# 서울특별시 종로구 청운효자동(1111051500)              3              3              3
# 서울특별시 종로구 사직동(1111053000)                9              2              3
# 서울특별시 종로구 삼청동(1111054000)                0              2              0
#
#                             2021년11월_계_99세 2021년11월_계_100세 이상
# 행정구역
# 서울특별시  (1100000000)                    816              2,010
# 서울특별시 종로구 (1111000000)                  27                 42
# 서울특별시 종로구 청운효자동(1111051500)              3                  2
# 서울특별시 종로구 사직동(1111053000)                1                  1
# 서울특별시 종로구 삼청동(1111054000)                2                  6
#
# [5 rows x 103 columns]

# %%
import pandas as pd
df = pd.read_csv('age_gangnam.csv', encoding='cp949', index_col = 0)
df = df.div(df['총인구수'], axis =0)     # 전체 데이터를 총인구수로 나눠서 비율로 변환
del df['총인구수'], df['연령구간인구수']  # 총인구수, 연령구간인구수 열 삭제
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '총인구수'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-e9a8f926d22b> in <module>
#       1 import pandas as pd
#       2 df = pd.read_csv('age_gangnam.csv', encoding='cp949', index_col = 0)
# ----> 3 df = df.div(df['총인구수'], axis =0)     # 전체 데이터를 총인구수로 나눠서 비율로 변환
#       4 del df['총인구수'], df['연령구간인구수']  # 총인구수, 연령구간인구수 열 삭제
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: '총인구수'

# %%
name = input('원하는 지역의 이름을 입력해주세요 : ') #2. 지역 이름 입력
a = df.index.str.contains(name) #3. 해당 행을 찾아서 해당 지역의 인구 구조를 저장
df2 = df[a]
df2
# Out:
# 원하는 지역의 이름을 입력해주세요 : 세곡동
#                           2021년11월_계_총인구수 2021년11월_계_연령구간인구수 2021년11월_계_0세  \
# 행정구역
# 서울특별시 강남구 세곡동(1168070000)          43,367             43,367           235
#
#                           2021년11월_계_1세 2021년11월_계_2세 2021년11월_계_3세  \
# 행정구역
# 서울특별시 강남구 세곡동(1168070000)           234           285           297
#
#                           2021년11월_계_4세 2021년11월_계_5세 2021년11월_계_6세  \
# 행정구역
# 서울특별시 강남구 세곡동(1168070000)           314           354           411
#
#                           2021년11월_계_7세  ... 2021년11월_계_91세 2021년11월_계_92세  \
# 행정구역                                     ...
# 서울특별시 강남구 세곡동(1168070000)           514  ...             52             40
#
#                           2021년11월_계_93세 2021년11월_계_94세 2021년11월_계_95세  \
# 행정구역
# 서울특별시 강남구 세곡동(1168070000)             30             30             13
#
#                           2021년11월_계_96세 2021년11월_계_97세 2021년11월_계_98세  \
# 행정구역
# 서울특별시 강남구 세곡동(1168070000)             11              6             10
#
#                           2021년11월_계_99세 2021년11월_계_100세 이상
# 행정구역
# 서울특별시 강남구 세곡동(1168070000)              7                  9
#
# [1 rows x 103 columns]

# %%
import matplotlib.pyplot as plt
plt.rc('font', family ='Malgun Gothic')
df2.T.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-c7ed1cf320ff> in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.rc('font', family ='Malgun Gothic')
# ----> 3 df2.T.plot()
#       4 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     267     def generate(self):
#     268         self._args_adjust()
# --> 269         self._compute_plot_data()
#     270         self._setup_subplots()
#     271         self._make_plot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     416         # no non-numeric frames or series allowed
#     417         if is_empty:
# --> 418             raise TypeError("no numeric data to plot")
#     419
#     420         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family ='Malgun Gothic')
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0) 
df = df.div(df['총인구수'], axis = 0)     # ①-1. 전체 데이터를 총인구수로 나눠서 비율로 변환
del df['총인구수'], df['연령구간인구수']  # ①-2. 총인구수, 연령구간인구수 열 삭제
name = input('원하는 지역의 이름을 입력해주세요 : ')  # ② 지역 이름 입력
a = df.index.str.contains(name)  # ③ 해당 행을 찾아서 해당 지역의 인구 구조를 저장
df2 = df[a]
df.loc[np.power(df.sub(df2.iloc[0], axis = 1), 2).sum(axis = 1).sort_values().index[:5]].T.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-bbdd797ab896> in <module>
#       3 import matplotlib.pyplot as plt
#       4 plt.rc('font', family ='Malgun Gothic')
# ----> 5 df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
#       6 df = df.div(df['총인구수'], axis = 0)     # ①-1. 전체 데이터를 총인구수로 나눠서 비율로 변환
#       7 del df['총인구수'], df['연령구간인구수']  # ①-2. 총인구수, 연령구간인구수 열 삭제
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1989         if kwds.get("compression") is None and encoding:
#    1990             if isinstance(src, str):
# -> 1991                 src = open(src, "rb")
#    1992                 self.handles.append(src)
#    1993
#
# FileNotFoundError: [Errno 2] No such file or directory: 'age.csv'
